# %%
import os
os.listdir()
# Out:
# ['.config', 'titanic.csv', 'sample_data']

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# -------------------------
# 1. EXTRACT (Load Data)
# -------------------------
data = pd.read_csv("titanic.csv")
print("Original Data:")
print(data.head())

# -------------------------
# 2. TRANSFORM
# -------------------------

# Keep only useful columns
data = data[['age', 'fare', 'pclass', 'survived']]

# Fill missing values
data['age'] = data['age'].fillna(data['age'].mean())
data['fare'] = data['fare'].fillna(data['fare'].mean())

# Scale age and fare
scaler = StandardScaler()
data[['age', 'fare']] = scaler.fit_transform(data[['age', 'fare']])

print("\nAfter Cleaning & Transformation:")
print(data.head())

# -------------------------
# 3. LOAD (Save Cleaned Data)
# -------------------------
data.to_csv("cleaned_titanic.csv", index=False)

print("\n✅ Cleaned data saved as cleaned_titanic.csv")
# Out:
# Original Data:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# After Cleaning & Transformation:
#         age      fare  pclass  survived
# 0 -0.592481 -0.502445       3         0
# 1  0.638789  0.786845       1         1
# 2 -0.284663 -0.488854       3         1
# 3  0.407926  0.420730       1         1
# 4  0.407926 -0.486337       3         0
#
# ✅ Cleaned data saved as cleaned_titanic.csv
